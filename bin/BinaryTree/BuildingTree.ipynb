# %%
# 105. Construct Binary Tree from Preorder and Inorder Traversal
# Solved
# Medium
# Topics
# premium lock icon
# Companies
# Given two integer arrays preorder and inorder where preorder is the preorder traversal of a binary tree and inorder is the inorder traversal of the same tree, construct and return the binary tree.

 

# Example 1:


# Input: preorder = [3,9,20,15,7], inorder = [9,3,15,20,7]
# Output: [3,9,20,null,null,15,7]
# Example 2:

# Input: preorder = [-1], inorder = [-1]
# Output: [-1]
 

# Constraints:

# 1 <= preorder.length <= 3000
# inorder.length == preorder.length
# -3000 <= preorder[i], inorder[i] <= 3000
# preorder and inorder consist of unique values.
# Each value of inorder also appears in preorder.
# preorder is guaranteed to be the preorder traversal of the tree.
# inorder is guaranteed to be the inorder traversal of the tree.


# Definition for a binary tree node.
from typing import List


class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def buildTree(self, preorder: List[int], inorder: List[int]) -> Optional[TreeNode]:
        if not preorder or not inorder:
            return None

        root_val = preorder[0]
        root = TreeNode(root_val)

        idx = inorder.index(root_val)
        # preorder = [3,9,20,15,7], inorder = [9,3,15,20,7]
        root.left = self.buildTree(preorder[1:1+idx], inorder[:idx])
        root.right = self.buildTree(preorder[1+idx:], inorder[idx+1:])

        return root

# %% [markdown]
# | Step | `preorder`          | `inorder`           | Root | Left Subtree Calls                | Right Subtree Calls                             |
# | ---- | ------------------- | ------------------- | ---- | --------------------------------- | ----------------------------------------------- |
# | 1    | `[3, 9, 20, 15, 7]` | `[9, 3, 15, 20, 7]` | `3`  | preorder: `[9]`, inorder: `[9]`   | preorder: `[20, 15, 7]`, inorder: `[15, 20, 7]` |
# | 2L   | `[9]`               | `[9]`               | `9`  | preorder: `[]`, inorder: `[]`     | preorder: `[]`, inorder: `[]`                   |
# | 2R   | `[20, 15, 7]`       | `[15, 20, 7]`       | `20` | preorder: `[15]`, inorder: `[15]` | preorder: `[7]`, inorder: `[7]`                 |
# | 3L   | `[15]`              | `[15]`              | `15` | preorder: `[]`, inorder: `[]`     | preorder: `[]`, inorder: `[]`                   |
# | 3R   | `[7]`               | `[7]`               | `7`  | preorder: `[]`, inorder: `[]`     | preorder: `[]`, inorder: `[]`                   |

# %%
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def buildTree(self, inorder: List[int], postorder: List[int]) -> Optional[TreeNode]:
        if not inorder or not postorder:
            return None

        root_val = postorder[-1]
        root = TreeNode(root_val)

        idx = inorder.index(root_val)
        root.left = self.buildTree(inorder[:idx], postorder[:idx])
        root.right = self.buildTree(inorder[idx+1:], postorder[idx:-1])

        return root

# %% [markdown]
# | Step | `inorder`           | `postorder`         | `root_val` | `idx` | Left Subtree Call            | Right Subtree Call                    |
# | ---- | ------------------- | ------------------- | ---------- | ----- | ---------------------------- | ------------------------------------- |
# | 1    | `[9, 3, 15, 20, 7]` | `[9, 15, 7, 20, 3]` | `3`        | `1`   | `buildTree([9], [9])`        | `buildTree([15, 20, 7], [15, 7, 20])` |
# | 2L   | `[9]`               | `[9]`               | `9`        | `0`   | `buildTree([], [])` → `None` | `buildTree([], [])` → `None`          |
# | 2R   | `[15, 20, 7]`       | `[15, 7, 20]`       | `20`       | `1`   | `buildTree([15], [15])`      | `buildTree([7], [7])`                 |
# | 3L   | `[15]`              | `[15]`              | `15`       | `0`   | `buildTree([], [])` → `None` | `buildTree([], [])` → `None`          |
# | 3R   | `[7]`               | `[7]`               | `7`        | `0`   | `buildTree([], [])` → `None` | `buildTree([], [])` → `None`          |

# %%
# inorder    = [9, 3, 15, 20, 7]
# postorder  = [9, 15, 7, 20, 3]

# # root_val is last of postorder
# root_val = 3
# root = TreeNode(3)

# # Index of 3 in inorder
# idx = inorder.index(3)  # idx = 1

# # Left Subtree:
# # inorder[:1]    = [9]
# # postorder[:1]  = [9]

# # Right Subtree:
# # inorder[2:]    = [15, 20, 7]
# # postorder[1:-1] = [15, 7, 20]

# root.left = buildTree([9], [9])
# root.right = buildTree([15, 20, 7], [15, 7, 20])



# 🟨 Call 2L (Left Subtree of 3)
# python
# Copy
# Edit
# inorder    = [9]
# postorder  = [9]

# root_val = 9
# root = TreeNode(9)

# idx = 0

# # Left Subtree:
# # inorder[:0]   = []
# # postorder[:0] = []

# # Right Subtree:
# # inorder[1:]    = []
# # postorder[0:-1]= []

# root.left = buildTree([], [])
# root.right = buildTree([], [])
# # Returns TreeNode(9)


# 🟦 Call 2R (Right Subtree of 3)
# python
# Copy
# Edit
# inorder    = [15, 20, 7]
# postorder  = [15, 7, 20]

# root_val = 20
# root = TreeNode(20)

# idx = inorder.index(20)  # 1

# # Left Subtree:
# # inorder[:1]    = [15]
# # postorder[:1]  = [15]

# # Right Subtree:
# # inorder[2:]    = [7]
# # postorder[1:-1] = [7]

# root.left = buildTree([15], [15])
# root.right = buildTree([7], [7])
# 🟥 Call 3L (Left Subtree of 20)
# python
# Copy
# Edit
# inorder    = [15]
# postorder  = [15]

# root_val = 15
# root = TreeNode(15)

# idx = 0

# # Left Subtree:
# # inorder[:0]   = []
# # postorder[:0] = []

# # Right Subtree:
# # inorder[1:]    = []
# # postorder[0:-1]= []

# root.left = buildTree([], [])
# root.right = buildTree([], [])
# # Returns TreeNode(15)
# 🟧 Call 3R (Right Subtree of 20)
# python
# Copy
# Edit
# inorder    = [7]
# postorder  = [7]

# root_val = 7
# root = TreeNode(7)

# idx = 0

# # Left Subtree:
# # inorder[:0]   = []
# # postorder[:0] = []

# # Right Subtree:
# # inorder[1:]    = []
# # postorder[0:-1]= []

# root.left = buildTree([], [])
# root.right = buildTree([], [])
# # Returns TreeNode(7)
# 🌳 Final Tree Reconstructed:
# markdown
# Copy
# Edit
#         3
#        / \
#       9   20
#           / \
#         15   7

# %%
class Solution:
    def constructFromPrePost(self, preorder: List[int], postorder: List[int]) -> Optional[TreeNode]:
        if not preorder:
            return None

        root_val = preorder[0]
        root = TreeNode(root_val)

        if len(preorder) == 1:
            return root

        # Left child is always the next element in preorder
        left_child_val = preorder[1]
        # Find it in postorder to determine left subtree size
        idx = postorder.index(left_child_val)

        # left subtree is of size (idx + 1)
        root.left = self.constructFromPrePost(preorder[1:idx+2], postorder[:idx+1])
        root.right = self.constructFromPrePost(preorder[idx+2:], postorder[idx+1:-1])

        return root
    


preorder = [1, 2, 4, 5, 3, 6, 7]
postorder = [4, 5, 2, 6, 7, 3, 1]

sol = Solution()
sol.constructFromPrePost(preorder, postorder)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 class Solution:
#       2     def constructFromPrePost(self, preorder: List[int], postorder: List[int]) -> Optional[TreeNode]:
#       3         if not preorder:
#
# Cell In[1], line 2, in Solution()
#       1 class Solution:
# ----> 2     def constructFromPrePost(self, preorder: List[int], postorder: List[int]) -> Optional[TreeNode]:
#       3         if not preorder:
#       4             return None
#
# NameError: name 'List' is not defined

# %% [markdown]
# | Call | `preorder`              | `postorder`             | `root_val` | `left_child_val` | `idx` (in post) | Left Subtree Call                             | Right Subtree Call                            |
# | ---- | ----------------------- | ----------------------- | ---------- | ---------------- | --------------- | --------------------------------------------- | --------------------------------------------- |
# | 1    | `[1, 2, 4, 5, 3, 6, 7]` | `[4, 5, 2, 6, 7, 3, 1]` | `1`        | `2`              | `2`             | preorder: `[2, 4, 5]`, postorder: `[4, 5, 2]` | preorder: `[3, 6, 7]`, postorder: `[6, 7, 3]` |
# | 2L   | `[2, 4, 5]`             | `[4, 5, 2]`             | `2`        | `4`              | `0`             | preorder: `[4]`, postorder: `[4]`             | preorder: `[5]`, postorder: `[5]`             |
# | 3L   | `[4]`                   | `[4]`                   | `4`        | —                | —               | returns TreeNode(4)                           | —                                             |
# | 3R   | `[5]`                   | `[5]`                   | `5`        | —                | —               | returns TreeNode(5)                           | —                                             |
# | 2R   | `[3, 6, 7]`             | `[6, 7, 3]`             | `3`        | `6`              | `0`             | preorder: `[6]`, postorder: `[6]`             | preorder: `[7]`, postorder: `[7]`             |
# | 4L   | `[6]`                   | `[6]`                   | `6`        | —                | —               | returns TreeNode(6)                           | —                                             |
# | 4R   | `[7]`                   | `[7]`                   | `7`        | —                | —               | returns TreeNode(7)                           | —                                             |
#
#
#
#
#
#
# | Call | preorder          | postorder         | root | left pre  | right pre |
# | ---- | ----------------- | ----------------- | ---- | --------- | --------- |
# | 1    | `[1,2,4,5,3,6,7]` | `[4,5,2,6,7,3,1]` | 1    | `[2,4,5]` | `[3,6,7]` |
# | 2    | `[2,4,5]`         | `[4,5,2]`         | 2    | `[4]`     | `[5]`     |
# | 3    | `[4]`             | `[4]`             | 4    | —         | —         |
# | 4    | `[5]`             | `[5]`             | 5    | —         | —         |
# | 5    | `[3,6,7]`         | `[6,7,3]`         | 3    | `[6]`     | `[7]`     |
# | 6    | `[6]`             | `[6]`             | 6    | —         | —         |
# | 7    | `[7]`             | `[7]`             | 7    | —         | —         |

# %%
# 🟢 Call 1 — Top Level
# python
# Copy
# Edit
# preorder  = [1, 2, 4, 5, 3, 6, 7]
# postorder = [4, 5, 2, 6, 7, 3, 1]

# root_val        = 1
# left_child_val  = preorder[1] = 2
# idx             = postorder.index(2) = 2

# # Left subtree:
# pre_left  = preorder[1:4]    = [2, 4, 5]
# post_left = postorder[:3]    = [4, 5, 2]

# # Right subtree:
# pre_right  = preorder[4:]    = [3, 6, 7]
# post_right = postorder[3:6]  = [6, 7, 3]

# # Recursive Calls:
# root.left  = constructFromPrePost([2, 4, 5], [4, 5, 2])
# root.right = constructFromPrePost([3, 6, 7], [6, 7, 3])
# 🟡 Call 2 — Left Subtree of 1
# python
# Copy
# Edit
# preorder  = [2, 4, 5]
# postorder = [4, 5, 2]

# root_val        = 2
# left_child_val  = 4
# idx             = postorder.index(4) = 0

# # Left subtree:
# pre_left  = preorder[1:2]    = [4]
# post_left = postorder[:1]    = [4]

# # Right subtree:
# pre_right  = preorder[2:]    = [5]
# post_right = postorder[1:2]  = [5]

# # Recursive Calls:
# root.left  = constructFromPrePost([4], [4])
# root.right = constructFromPrePost([5], [5])
# 🟣 Call 3 — Left Subtree of 2
# python
# Copy
# Edit
# preorder  = [4]
# postorder = [4]

# root_val = 4
# # Leaf node
# return TreeNode(4)
# 🔵 Call 4 — Right Subtree of 2
# python
# Copy
# Edit
# preorder  = [5]
# postorder = [5]

# root_val = 5
# # Leaf node
# return TreeNode(5)
# Now we return TreeNode(2) with:

# left = TreeNode(4)

# right = TreeNode(5)

# 🔴 Call 5 — Right Subtree of 1
# python
# Copy
# Edit
# preorder  = [3, 6, 7]
# postorder = [6, 7, 3]

# root_val        = 3
# left_child_val  = 6
# idx             = postorder.index(6) = 0

# # Left subtree:
# pre_left  = preorder[1:2]    = [6]
# post_left = postorder[:1]    = [6]

# # Right subtree:
# pre_right  = preorder[2:]    = [7]
# post_right = postorder[1:2]  = [7]

# # Recursive Calls:
# root.left  = constructFromPrePost([6], [6])
# root.right = constructFromPrePost([7], [7])
# 🟤 Call 6 — Left Subtree of 3
# python
# Copy
# Edit
# preorder  = [6]
# postorder = [6]

# root_val = 6
# # Leaf node
# return TreeNode(6)
# ⚫ Call 7 — Right Subtree of 3
# python
# Copy
# Edit
# preorder  = [7]
# postorder = [7]

# root_val = 7
# # Leaf node
# return TreeNode(7)
# Now return TreeNode(3) with:

# left = TreeNode(6)

# right = TreeNode(7)

# ✅ Final Return (Root = 1)
# Return TreeNode(1) with:

# left = TreeNode(2)

# left = TreeNode(4)

# right = TreeNode(5)

# right = TreeNode(3)

# left = TreeNode(6)

# right = TreeNode(7)

# 🌳 Final Tree Built:
# markdown
# Copy
# Edit
#         1
#       /   \
#      2     3
#     / \   / \
#    4   5 6   7
