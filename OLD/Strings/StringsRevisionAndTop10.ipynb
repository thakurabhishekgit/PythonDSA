# %% [markdown]
# ✅ Concept Summary:
#
# Sequence of characters, immutable in Java & Python.
#
# Common ops: reverse, compare, substring, palindrome check.
#
# ⚡ Key Patterns:
#
# Sliding Window (e.g. Longest substring without repeating chars)
#
# HashMap + Frequency Count
#
# Two-Pointer (Palindrome, Anagram)
#
# KMP (pattern searching)
#
# StringBuilder usage (for concatenation efficiency)
#
# | Type           | Question                              | Concept              |
# | -------------- | ------------------------------------- | -------------------- |
# | Reversal       | Reverse words in a string             | Two Pointers         |
# | Palindrome     | Longest Palindromic Substring         | Expand Around Center |
# | Frequency      | Check if two strings are anagrams     | HashMap              |
# | Pattern Search | Implement strStr() / substring search | KMP                  |
# | Encoding       | Count and Say                         | String traversal     |
# | Sliding Window | Longest substring without repeating   | HashSet              |
