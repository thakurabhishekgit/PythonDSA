# %% [markdown]
# ✅ Stack:
#
# LIFO (Last In First Out)
#
# Common ops: push, pop, peek
#
# ✅ Queue:
#
# FIFO (First In First Out)
#
# Common ops: enqueue, dequeue
#
# ⚡ Key Patterns:
#
# Stack used in parentheses validation, histogram problems
#
# Queue used in BFS traversal
#
# | Question                     | Concept         |
# | ---------------------------- | --------------- |
# | Valid Parentheses            | Stack           |
# | Next Greater Element         | Stack           |
# | Min Stack                    | Auxiliary Stack |
# | Implement Stack using Queues | Queue logic     |
# | Implement Queue using Stacks | Stack logic     |
# | Rotten Oranges               | BFS with Queue  |
# | Sliding Window Maximum       | Deque           |
