# %% [markdown]
# ✅ Concept:
#
# Non-linear data structure. Root + Children.
#
# Types: Binary Tree, Binary Search Tree (BST), AVL, etc.
#
# ⚡ Traversals:
#
# DFS (Inorder, Preorder, Postorder)
#
# BFS (Level Order)
#
# | Question                 | Concept           |
# | ------------------------ | ----------------- |
# | Max Depth of Binary Tree | DFS               |
# | Inorder Traversal        | Recursion / Stack |
# | Symmetric Tree           | Recursion         |
# | Lowest Common Ancestor   | Recursive Logic   |
# | Validate BST             | Range Checking    |
# | Diameter of Binary Tree  | Depth calculation |
#
#
#
# | Type                         | Definition                                                           | Example / Notes                        |
# | ---------------------------- | -------------------------------------------------------------------- | -------------------------------------- |
# | **General Tree**             | Any node can have multiple children                                  | Used in hierarchies (filesystems)      |
# | **Binary Tree**              | Each node has **≤ 2 children**                                       | Left + Right                           |
# | **Full Binary Tree**         | Every node has 0 or 2 children                                       | Perfectly filled at all internal nodes |
# | **Complete Binary Tree**     | All levels except last are filled, and last filled **left to right** | Heaps                                  |
# | **Perfect Binary Tree**      | All internal nodes have 2 children and all leaves are at same depth  | Height = log₂(n+1) - 1                 |
# | **Balanced Binary Tree**     | Height difference between left & right subtree ≤ 1 for all nodes     | Improves efficiency                    |
# | **Degenerate (Skewed)**      | Every parent has only one child                                      | Worst-case (like linked list)          |
# | **Binary Search Tree (BST)** | Left < Root < Right                                                  | Enables fast search                    |
# | **AVL Tree**                 | Self-balancing BST (height diff ≤ 1)                                 | Rotations used                         |
# | **Red-Black Tree**           | Balanced BST using color rules                                       | Used in Java’s `TreeMap`, `TreeSet`    |
# | **B-Tree**                   | Multi-way self-balancing tree used in databases                      | Generalization of BST                  |
# | **B+ Tree**                  | Leaf nodes linked for faster range queries                           | Used in DB indexing                    |
# | **Trie (Prefix Tree)**       | Used for string search, autocomplete                                 | Words sharing prefixes                 |
#
#
#
#
# 🟢 Depth-First Search (DFS)
#
# Inorder (Left, Root, Right) → Used in BST for sorted order
#
# Preorder (Root, Left, Right) → Used for copying trees
#
# Postorder (Left, Right, Root) → Used for deletion
#
# Example Tree
#
#         1
#       /   \
#      2     3
#     / \   /
#    4  5  6
#
#
#
#    | Traversal | Output      | Used For                  |
# | --------- | ----------- | ------------------------- |
# | Inorder   | 4 2 5 1 6 3 | Get sorted order from BST |
# | Preorder  | 1 2 4 5 3 6 | Create copy of tree       |
# | Postorder | 4 5 2 6 3 1 | Delete / free nodes       |
#
# \
#
# 🌾 4️⃣ Binary Search Tree (BST)
#
# Properties:
#
# Left subtree values < root value
#
# Right subtree values > root value
#
# Inorder traversal → sorted order
#
#
# | Operation | Time | Description                                |
# | --------- | ---- | ------------------------------------------ |
# | Search    | O(h) | Traverse left/right based on value         |
# | Insert    | O(h) | Place in correct position                  |
# | Delete    | O(h) | Replace with inorder successor/predecessor |
#
#
#
# | Operation         | BST               | Balanced BST (AVL / RBT) |
# | ----------------- | ----------------- | ------------------------ |
# | Search            | O(h) = O(n) worst | O(log n)                 |
# | Insert            | O(h)              | O(log n)                 |
# | Delete            | O(h)              | O(log n)                 |
# | Traversal         | O(n)              | O(n)                     |
# | Space (recursive) | O(h)              | O(log n)                 |

# %% [markdown]
# | Concept                          | Explanation                                   | Time Complexity                |
# | -------------------------------- | --------------------------------------------- | ------------------------------ |
# | **Definition**                   | Left subtree < root < right subtree           | —                              |
# | **Search / Insert / Delete**     | Use binary property for efficient lookup      | Average: O(log n), Worst: O(n) |
# | **BST Validation**               | Check if inorder traversal is sorted          | Common interview question      |
# | **Lowest Common Ancestor (LCA)** | For BST, easy to find using value comparisons | O(h)                           |
# | **Successor & Predecessor**      | Inorder next and previous nodes               | O(h)                           |
#
#
#
# | Type                                    | Order                                           | Technique | Time |
# | --------------------------------------- | ----------------------------------------------- | --------- | ---- |
# | **Preorder (Root–Left–Right)**          | Used in cloning and prefix expression           | DFS       | O(n) |
# | **Inorder (Left–Root–Right)**           | For BST gives sorted output                     | DFS       | O(n) |
# | **Postorder (Left–Right–Root)**         | Used for deleting or evaluating expression tree | DFS       | O(n) |
# | **Level Order**                         | BFS using queue                                 | BFS       | O(n) |
# | **Reverse Level Order, Zigzag, Spiral** | Variants used for pattern questions             | BFS       | O(n) |
#
#
#
# | Tree Type                              | Key Idea                                                             | Use Case                                  |
# | -------------------------------------- | -------------------------------------------------------------------- | ----------------------------------------- |
# | **AVL Tree**                           | Self-balancing BST; height diff ≤ 1; uses rotations (LL, RR, LR, RL) | When frequent lookups and updates needed  |
# | **Red-Black Tree**                     | Balances via coloring (red/black rules), ensures O(log n) height     | Used in language libraries (`map`, `set`) |
# | **B-Tree**                             | Multiway balanced tree used in databases for large disk blocks       | Disk-based indexing                       |
# | **B+ Tree**                            | All data stored in leaves; leaf nodes linked                         | Database indexing (MySQL, file systems)   |
# | **Segment Tree**                       | For range queries (sum, min, max)                                    | Used in competitive programming           |
# | **Fenwick Tree (Binary Indexed Tree)** | Space-efficient range query structure                                | Similar to segment tree but simpler       |
# | **Trie (Prefix Tree)**                 | Stores strings by characters                                         | Autocomplete, spell-checkers              |

# %% [markdown]
# | Operation | Balanced BST | Skewed BST | Heap     | Trie                 |
# | --------- | ------------ | ---------- | -------- | -------------------- |
# | Search    | O(log n)     | O(n)       | O(n)     | O(L)                 |
# | Insert    | O(log n)     | O(n)       | O(log n) | O(L)                 |
# | Delete    | O(log n)     | O(n)       | O(log n) | O(L)                 |
# | Space     | O(n)         | O(n)       | O(n)     | O(ALPHABET_SIZE × L) |
